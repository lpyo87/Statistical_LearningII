# %%
#Dependencies
import tensorflow as tf
import tensorflow.keras as kr
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
import pandas as pd

# %%
# Cargamos el conjunto de datos Iris
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
names = ['sepal-length', 'sepal-width', 'petal-length', 'petal-width', 'class']
dataset = pd.read_csv(url, names=names)

# %%
# Dividimos las columnas del dataset en variables independientes (X) y dependientes (Y)
X = dataset.iloc[:, 0:4].values
Y = dataset.iloc[:, 4].values

# %%
# Codificamos las clases como números enteros
encoder = LabelEncoder()
encoder.fit(Y)
encoded_Y = encoder.transform(Y)

# %%
# Convertimos los enteros en variables dummy (one hot encoding)
dummy_y = kr.utils.to_categorical(encoded_Y)

# %%
# Dividimos el dataset en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, dummy_y, test_size=0.20, random_state=1)

# %% [markdown]
# # Creamos la red neuronal
#
# Inicializamos la red neuronal utilizando la clase Sequential de Keras. Esta es la clase de modelo más simple en Keras, apropiada para una pila simple de capas donde cada capa tiene exactamente un tensor de entrada y un tensor de salida.

# %%
model = tf.keras.models.Sequential()

# %% [markdown]
# Agregamos una capa densa (también conocida como totalmente conectada) a la red neuronal. Una capa densa es una capa de red neuronal donde cada una de sus neuronas está conectada a cada neurona en la capa anterior.
#
# Esta capa tiene 8 neuronas (unidades), la función de activación ReLU y espera filas de datos con 4 variables (el parámetro input_dim=4, que es el número de características de entrada).
#
# La función de activación ReLU (Rectified Linear Unit) es una función de activación que producirá el input directamente si es positivo, de lo contrario, producirá cero.

# %%
model.add(kr.layers.Dense(8, input_dim=4, activation='relu'))

# %% [markdown]
# Agregamos otra capa densa a la red neuronal. Esta capa es la capa de salida, que tiene 3 neuronas porque hay 3 clases en el conjunto de datos Iris. La función de activación 'softmax' es una generalización de la función sigmoide que la convierte en más adecuada para la clasificación de múltiples clases.

# %%
model.add(kr.layers.Dense(3, activation='softmax'))

# %% [markdown]
# # Compilamos el modelo
#
# Antes de entrenar el modelo, necesitamos configurar el proceso de aprendizaje. Esto se hace en la etapa de compilación, donde se especifican la función de pérdida, el optimizador y las métricas de evaluación.
#
# La 'categorical_crossentropy' es la función de pérdida que se utiliza para problemas de clasificación multiclase. Es más adecuada para conjuntos de datos de clases equilibradas.
#
# 'Adam' es un método de optimización basado en el gradiente descendente que se utiliza para actualizar los pesos de la red.
#
# La 'accuracy' es la métrica de evaluación utilizada para medir el rendimiento del modelo. En este caso, mide el porcentaje de predicciones correctas sobre todas las predicciones realizadas.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# # Tensorboard

# %%
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir='./logs')

# %% [markdown]
# # Ajustamos el modelo
#
# Aquí es donde ocurre el entrenamiento del modelo. Proporcionamos los datos de entrenamiento y etiquetas a la red, especificamos el número de épocas y el tamaño del batch.
#
# Las épocas son el número de veces que el modelo pasa por todo el conjunto de datos de entrenamiento.
#
# El tamaño del batch es el número de muestras que se pasan a través de la red antes de que los pesos sean actualizados.

# %%
model.fit(X_train, y_train, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1151 - accuracy: 0.9583
# Epoch 2/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1098 - accuracy: 0.9583
# Epoch 3/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1101 - accuracy: 0.9583
# Epoch 4/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1053 - accuracy: 0.9583
# Epoch 5/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1093 - accuracy: 0.9667
# Epoch 6/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1092 - accuracy: 0.9583
# Epoch 7/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1057 - accuracy: 0.9583
# Epoch 8/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1048 - accuracy: 0.9583
# Epoch 9/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1041 - accuracy: 0.9583
# Epoch 10/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1037 - accuracy: 0.9583
# Epoch 11/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1040 - accuracy: 0.9583
# Epoch 12/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1077 - accuracy: 0.9583
# Epoch 13/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1045 - accuracy: 0.9583
# Epoch 14/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1025 - accuracy: 0.9583
# Epoch 15/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1024 - accuracy: 0.9583
# Epoch 16/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1029 - accuracy: 0.9583
# Epoch 17/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1023 - accuracy: 0.9583
# Epoch 18/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1007 - accuracy: 0.9583
# Epoch 19/150
# 12/12 [==============================] - 0s 1000us/step - loss: 0.1011 - accuracy: 0.9583
# Epoch 20/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1007 - accuracy: 0.9583
# Epoch 21/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1005 - accuracy: 0.9583
# Epoch 22/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0995 - accuracy: 0.9583
# Epoch 23/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0992 - accuracy: 0.9583
# Epoch 24/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0995 - accuracy: 0.9583
# Epoch 25/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0984 - accuracy: 0.9583
# Epoch 26/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0978 - accuracy: 0.9583
# Epoch 27/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0990 - accuracy: 0.9583
# Epoch 28/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.1001 - accuracy: 0.9500
# Epoch 29/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0972 - accuracy: 0.9667
# Epoch 30/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0971 - accuracy: 0.9583
# Epoch 31/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0971 - accuracy: 0.9583
# Epoch 32/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0963 - accuracy: 0.9583
# Epoch 33/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0956 - accuracy: 0.9583
# Epoch 34/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0952 - accuracy: 0.9583
# Epoch 35/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0950 - accuracy: 0.9583
# Epoch 36/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0962 - accuracy: 0.9583
# Epoch 37/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0951 - accuracy: 0.9583
# Epoch 38/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0955 - accuracy: 0.9583
# Epoch 39/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9583
# Epoch 40/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.9583
# Epoch 41/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0936 - accuracy: 0.9583
# Epoch 42/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0976 - accuracy: 0.9583
# Epoch 43/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0930 - accuracy: 0.9583
# Epoch 44/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0933 - accuracy: 0.9583
# Epoch 45/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0921 - accuracy: 0.9583
# Epoch 46/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0940 - accuracy: 0.9583
# Epoch 47/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0925 - accuracy: 0.9583
# Epoch 48/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0917 - accuracy: 0.9583
# Epoch 49/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0914 - accuracy: 0.9583
# Epoch 50/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0917 - accuracy: 0.9583
# Epoch 51/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0936 - accuracy: 0.9583
# Epoch 52/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0903 - accuracy: 0.9583
# Epoch 53/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 0.9583
# Epoch 54/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0910 - accuracy: 0.9583
# Epoch 55/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0901 - accuracy: 0.9583
# Epoch 56/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0901 - accuracy: 0.9583
# Epoch 57/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0904 - accuracy: 0.9583
# Epoch 58/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0892 - accuracy: 0.9583
# Epoch 59/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0894 - accuracy: 0.9583
# Epoch 60/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0891 - accuracy: 0.9583
# Epoch 61/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0884 - accuracy: 0.9583
# Epoch 62/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0885 - accuracy: 0.9583
# Epoch 63/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0888 - accuracy: 0.9583
# Epoch 64/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0881 - accuracy: 0.9583
# Epoch 65/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0878 - accuracy: 0.9583
# Epoch 66/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0875 - accuracy: 0.9583
# Epoch 67/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0884 - accuracy: 0.9583
# Epoch 68/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0875 - accuracy: 0.9583
# Epoch 69/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0878 - accuracy: 0.9583
# Epoch 70/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0871 - accuracy: 0.9583
# Epoch 71/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0868 - accuracy: 0.9583
# Epoch 72/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0868 - accuracy: 0.9667
# Epoch 73/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0884 - accuracy: 0.9583
# Epoch 74/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0871 - accuracy: 0.9583
# Epoch 75/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0890 - accuracy: 0.9583
# Epoch 76/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0863 - accuracy: 0.9667
# Epoch 77/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0860 - accuracy: 0.9583
# Epoch 78/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0862 - accuracy: 0.9583
# Epoch 79/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0857 - accuracy: 0.9583
# Epoch 80/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0848 - accuracy: 0.9583
# Epoch 81/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0847 - accuracy: 0.9583
# Epoch 82/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0845 - accuracy: 0.9583
# Epoch 83/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0850 - accuracy: 0.9667
# Epoch 84/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0846 - accuracy: 0.9583
# Epoch 85/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0845 - accuracy: 0.9583
# Epoch 86/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0845 - accuracy: 0.9583
# Epoch 87/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0843 - accuracy: 0.9667
# Epoch 88/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0842 - accuracy: 0.9667
# Epoch 89/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0831 - accuracy: 0.9667
# Epoch 90/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0840 - accuracy: 0.9583
# Epoch 91/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0840 - accuracy: 0.9583
# Epoch 92/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0839 - accuracy: 0.9583
# Epoch 93/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0830 - accuracy: 0.9667
# Epoch 94/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.9583
# Epoch 95/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0826 - accuracy: 0.9583
# Epoch 96/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0826 - accuracy: 0.9583
# Epoch 97/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.9667
# Epoch 98/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0819 - accuracy: 0.9667
# Epoch 99/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0830 - accuracy: 0.9667
# Epoch 100/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0814 - accuracy: 0.9667
# Epoch 101/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9583
# Epoch 102/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0819 - accuracy: 0.9583
# Epoch 103/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0817 - accuracy: 0.9667
# Epoch 104/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0833 - accuracy: 0.9667
# Epoch 105/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0815 - accuracy: 0.9667
# Epoch 106/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0816 - accuracy: 0.9583
# Epoch 107/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0814 - accuracy: 0.9583
# Epoch 108/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0810 - accuracy: 0.9583
# Epoch 109/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0818 - accuracy: 0.9583
# Epoch 110/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9667
# Epoch 111/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0803 - accuracy: 0.9667
# Epoch 112/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0825 - accuracy: 0.9583
# Epoch 113/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0800 - accuracy: 0.9750
# Epoch 114/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0802 - accuracy: 0.9583
# Epoch 115/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0806 - accuracy: 0.9583
# Epoch 116/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0798 - accuracy: 0.9583
# Epoch 117/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0795 - accuracy: 0.9583
# Epoch 118/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0801 - accuracy: 0.9667
# Epoch 119/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0794 - accuracy: 0.9667
# Epoch 120/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0794 - accuracy: 0.9667
# Epoch 121/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0795 - accuracy: 0.9583
# Epoch 122/150
# 12/12 [==============================] - 0s 2ms/step - loss: 0.0792 - accuracy: 0.9583
# Epoch 123/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0797 - accuracy: 0.9583
# Epoch 124/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0795 - accuracy: 0.9583
# Epoch 125/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0787 - accuracy: 0.9667
# Epoch 126/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0805 - accuracy: 0.9500
# Epoch 127/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0796 - accuracy: 0.9583
# Epoch 128/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0802 - accuracy: 0.9667
# Epoch 129/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 0.9667
# Epoch 130/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0786 - accuracy: 0.9750
# Epoch 131/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0790 - accuracy: 0.9583
# Epoch 132/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9583
# Epoch 133/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0799 - accuracy: 0.9667
# Epoch 134/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0777 - accuracy: 0.9667
# Epoch 135/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0785 - accuracy: 0.9583
# Epoch 136/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0779 - accuracy: 0.9583
# Epoch 137/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0794 - accuracy: 0.9583
# Epoch 138/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0794 - accuracy: 0.9583
# Epoch 139/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0788 - accuracy: 0.9583
# Epoch 140/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0780 - accuracy: 0.9583
# Epoch 141/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0779 - accuracy: 0.9583
# Epoch 142/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 0.9667
# Epoch 143/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0770 - accuracy: 0.9667
# Epoch 144/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0771 - accuracy: 0.9667
# Epoch 145/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0772 - accuracy: 0.9583
# Epoch 146/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0776 - accuracy: 0.9667
# Epoch 147/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0769 - accuracy: 0.9583
# Epoch 148/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0772 - accuracy: 0.9583
# Epoch 149/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0777 - accuracy: 0.9667
# Epoch 150/150
# 12/12 [==============================] - 0s 1ms/step - loss: 0.0768 - accuracy: 0.9667

# %% [markdown]
# # Evaluamos el modelo
#
# Después del entrenamiento, queremos evaluar cómo se desempeña nuestro modelo en datos nunca vistos antes. Para eso usamos el método 'evaluate'.
#
# Este método devuelve la pérdida y las métricas de evaluación especificadas en el método 'compile'. En este caso, nos devolverá la pérdida categórica cruzada y la precisión.

# %%
loss, accuracy = model.evaluate(X_test, y_test)

# Imprimimos la precisión del modelo, multiplicada por 100 para obtener un porcentaje.
print('Precisión: %.2f' % (accuracy*100))
# Out:
# 1/1 [==============================] - 0s 72ms/step - loss: 0.0706 - accuracy: 1.0000
# Precisión: 100.00
